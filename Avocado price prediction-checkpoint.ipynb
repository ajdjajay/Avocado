# %% [markdown]
# # Purpose

# %% [markdown]
# The purpose of this notebook is to perform a robust analysis of the data. It will include: data cleaning, descriptive analysis, epxloratory data analysis, data analysis with data wranging, classification and regression models.

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
Avocado=pd.read_csv('avocado.csv')

# %%
Avocado.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  04-02-2018          1.63      17074.83  2046.96  1529.20
# 18245           8  28-01-2018          1.71      13888.04  1191.70  3431.50
# 18246           9  21-01-2018          1.87      13766.76  1191.92  2452.79
# 18247          10  14-01-2018          1.93      16205.22  1527.63  2981.04
# 18248          11  07-01-2018          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
Avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1           1  20-12-2015          1.35      54876.98   674.28   44638.81
# 2           2  13-12-2015          0.93     118220.22   794.70  109149.67
# 3           3  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4           4  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
Avocado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
Avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
Avocado.skew()
# Out:
# Unnamed: 0       0.108334
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# dtype: float64

# %%
Avocado.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# Observed:
#
# 1.Date,type,region are objects 2.Others are float type

# %%
Avocado['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
Avocado1=Avocado.drop(['year','Unnamed: 0'],axis=1)

# %%
Avocado1.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  region
# 0     8696.87     8603.62       93.25          0.0  conventional  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  Albany

# %%
Avocado1.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    1.937313e+07  1.338459e+07  5.719097e+06  551693.650000

# %% [markdown]
# Observed:
#
# 1.In columns Total bags,small bags,large bags 75% has maximum value 2.In columns Total bags,small bags,large bags mean and std has more difference and has outliers

# %%
Avocado1.type.unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %% [markdown]
# Observed:
#
# 1.In type column are in one value hence we drop the column

# %%
Avocado=Avocado1.drop(['type'],axis=1)

# %%
Avocado
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1      20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2      13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3      06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4      29-11-2015          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  04-02-2018          1.63      17074.83  2046.96    1529.20    0.00
# 18245  28-01-2018          1.71      13888.04  1191.70    3431.50    0.00
# 18246  21-01-2018          1.87      13766.76  1191.92    2452.79  727.94
# 18247  14-01-2018          1.93      16205.22  1527.63    2981.04  727.01
# 18248  07-01-2018          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags            region
# 0         8696.87     8603.62       93.25          0.0            Albany
# 1         9505.56     9408.07       97.49          0.0            Albany
# 2         8145.35     8042.21      103.14          0.0            Albany
# 3         5811.16     5677.40      133.76          0.0            Albany
# 4         6183.95     5986.26      197.69          0.0            Albany
# ...           ...         ...         ...          ...               ...
# 18244    13498.67    13066.82      431.85          0.0  WestTexNewMexico
# 18245     9264.84     8940.04      324.80          0.0  WestTexNewMexico
# 18246     9394.11     9351.80       42.31          0.0  WestTexNewMexico
# 18247    10969.54    10919.54       50.00          0.0  WestTexNewMexico
# 18248    12014.15    11988.14       26.01          0.0  WestTexNewMexico
#
# [18249 rows x 11 columns]

# %% [markdown]
# # Checking for missing values

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(Avocado.isnull())
plt.show()

# %% [markdown]
# Observed: 1.we observed that there are no null values

# %% [markdown]
# # To check the correlation

# %%
Avo=Avocado.corr()

# %%
Avo
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592
# Total Volume    0.963047    0.967238    0.880640     0.747157
# 4046            0.920057    0.925280    0.838645     0.699377
# 4225            0.905787    0.916031    0.810015     0.688809
# 4770            0.792314    0.802733    0.698471     0.679861
# Total Bags      1.000000    0.994335    0.943009     0.804233
# Small Bags      0.994335    1.000000    0.902589     0.806845
# Large Bags      0.943009    0.902589    1.000000     0.710858
# XLarge Bags     0.804233    0.806845    0.710858     1.000000

# %%
plt.figure(figsize=(16,10))
sns.heatmap(Avo,annot=True,cmap='winter')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Observed: 1.from above map the average price is highly correlated

# %% [markdown]
# Data Visualiaztion
#
# univariate Analysis

# %%
plt.figure(figsize=(100,50))
Avocado['AveragePrice'].plot.bar()
plt.show()

# %%
Avocado['Small Bags'].plot.hist()
plt.title('Histogram of Small Bags column')
plt.show()

# %%
Avocado['Large Bags'].plot.hist()
plt.title('Histogram of Large Bags column')
plt.show()

# %%
sns.set(style='whitegrid')
sns.violinplot(Avocado['Total Bags'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total Bags'>

# %%
plt.figure(figsize=(10,10))
sns.set(style='white')
plt.scatter(Avocado['AveragePrice'],Avocado['Total Volume'])
plt.xlabel('AveragePrice')
# Out:
# Text(0.5, 0, 'AveragePrice')

# %%
Avocado=Avocado.drop(['Date'],axis=1)

# %%
Avocado
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags            region
# 0         8603.62       93.25          0.0            Albany
# 1         9408.07       97.49          0.0            Albany
# 2         8042.21      103.14          0.0            Albany
# 3         5677.40      133.76          0.0            Albany
# 4         5986.26      197.69          0.0            Albany
# ...           ...         ...          ...               ...
# 18244    13066.82      431.85          0.0  WestTexNewMexico
# 18245     8940.04      324.80          0.0  WestTexNewMexico
# 18246     9351.80       42.31          0.0  WestTexNewMexico
# 18247    10919.54       50.00          0.0  WestTexNewMexico
# 18248    11988.14       26.01          0.0  WestTexNewMexico
#
# [18249 rows x 10 columns]

# %%
plt.figure(figsize=(12,16))
sns.regplot(x='Total Bags',y='region',data=Avocado,fit_reg=False)
plt.show()

# %%
plt.figure(figsize=(12,16))
sns.regplot(x='Total Volume',y='region',data=Avocado,fit_reg=False)
plt.show()

# %%
plt.figure(figsize=(12,16))
sns.regplot(x='AveragePrice',y='region',data=Avocado,fit_reg=False)
plt.show()

# %% [markdown]
# # Converting

# %%
Avocado.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# region           object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
Avocado['region']=le.fit_transform(Avocado['region'])

# %% [markdown]
# # To Check the Distribution of skewness

# %%
collist=Avocado.columns.values
ncol=12
nrow=10

# %%
plt.figure(figsize=(50,20))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.distplot(Avocado[collist[i]],color='blue')
    plt.tight_layout()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Observed: 1.Data is more skewed

# %%
Avocado.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# region           0.000030
# dtype: float64

# %%
for col in Avocado.columns:
    if Avocado[col].skew()>0.55:
        Avocado[col]=np.log1p(Avocado[col])

# %%
Avocado.skew()
# Out:
# AveragePrice    0.138629
# Total Volume    0.088098
# 4046           -0.328195
# 4225           -0.486654
# 4770            0.099986
# Total Bags     -0.218874
# Small Bags     -0.622148
# Large Bags     -0.547765
# XLarge Bags     1.176494
# region          0.000030
# dtype: float64

# %% [markdown]
# Plotting outliers

# %%
Avocado.shape
# Out:
# (18249, 10)

# %%
Avocado['4046'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observed:
#
# 1. There are no outliers

# %%
Avocado.plot(kind='box',subplots=True,layout=(2,5))
# Out:
# AveragePrice       AxesSubplot(0.125,0.536818;0.133621x0.343182)
# Total Volume    AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# 4046             AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# 4225            AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# 4770            AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Total Bags            AxesSubplot(0.125,0.125;0.133621x0.343182)
# Small Bags         AxesSubplot(0.285345,0.125;0.133621x0.343182)
# Large Bags          AxesSubplot(0.44569,0.125;0.133621x0.343182)
# XLarge Bags        AxesSubplot(0.606034,0.125;0.133621x0.343182)
# region             AxesSubplot(0.766379,0.125;0.133621x0.343182)
# dtype: object

# %% [markdown]
# Observed: 1.there are outliers in averageprice,total bags,small bags,and total baga

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore
z_score=abs(zscore(Avocado))
print(Avocado.shape)
Avo=Avocado.loc[(z_score<3).all(axis=1)]
print(Avo.shape)
# Out:
# (18249, 10)
# (17928, 10)

# %% [markdown]
# Observed: 1.Outliers are removed 2.15 rows are removed

# %% [markdown]
# # Model Training

# %%
df_x=Avocado.drop(columns=['AveragePrice'])

# %%
y=pd.DataFrame(Avocado['AveragePrice'])

# %%
df_x.head()
# Out:
#    Total Volume      4046       4225      4770  Total Bags  Small Bags  \
# 0     11.070344  6.944801  10.905146  3.895080    9.070833    9.060055
# 1     10.912867  6.515127  10.706381  4.083115    9.159737    9.149429
# 2     11.680313  6.679222  11.600485  4.879007    9.005325    8.992584
# 3     11.277116  7.032624  11.184108  4.298373    8.667708    8.644425
# 4     10.840377  6.848515  10.688288  4.340944    8.729874    8.697389
#
#    Large Bags  XLarge Bags  region
# 0    4.545951          0.0       0
# 1    4.589955          0.0       0
# 2    4.645736          0.0       0
# 3    4.903495          0.0       0
# 4    5.291746          0.0       0

# %%
y.head()
# Out:
#    AveragePrice
# 0      0.845868
# 1      0.854415
# 2      0.657520
# 3      0.732368
# 4      0.824175

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x.shape
# Out:
# (18249, 9)

# %%
y.shape
# Out:
# (18249, 1)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# %%
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}
model=Ridge()
grid=GridSearchCV(estimator=model,param_grid=alphavalue,cv=5)
grid.fit(x,y)
print(grid)
print(grid.best_estimator_.alpha)
print(grid.best_params_)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0]})
# 1
# {'alpha': 1}

# %%
from sklearn import svm
svr=svm.SVR()
parameters={'kernel':['linear','rbf','poly'],'C':[1.0]}
gd=GridSearchCV(svr,parameters)
gd.fit(x,y)
sorted(gd.cv_results_.keys())
print(gd.best_params_)
# Out:
# {'C': 1.0, 'kernel': 'rbf'}

# %%
max_r_score=0
for r_state in range(40,1400):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r_scr=r2_score(y_test,y_pred)
    if r_scr>max_r_score:
        max_r_score=r_scr
        final_r_state=r_state
print('max r2 score corresponding to',final_r_state,'is',max_r_score)
# Out:
# max r2 score corresponding to 1176 is 0.4629970817851994

# %%
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(kernel='linear'),Lasso(),Ridge(alpha=1),ElasticNet(),RandomForestRegressor(),AdaBoostRegressor()]
for m in model:
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=1232,test_size=.20)
    m.fit(x_train,y_train)
    print('Score of',m,'is:',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('Error:')
    print('Mean Absolute Error :',mean_absolute_error(y_test,predm))
    print('Mean Squared Error :',mean_squared_error(y_test,predm))
    print('r2_score',r2_score(y_test,predm))
    print('*******************************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression() is: 0.436694494750965
# Error:
# Mean Absolute Error : 0.09982603234194602
# Mean Squared Error : 0.015577072443047534
# r2_score 0.42122374613024616
# *******************************************************************************************************
#
#
# Score of DecisionTreeRegressor() is: 1.0
# Error:
# Mean Absolute Error : 0.06346949102577822
# Mean Squared Error : 0.009010987797568346
# r2_score 0.6651908899948386
# *******************************************************************************************************
#
#
# Score of KNeighborsRegressor() is: 0.8834732291735075
# Error:
# Mean Absolute Error : 0.05046995933821953
# Mean Squared Error : 0.005075954376799321
# r2_score 0.8113996150586736
# *******************************************************************************************************
#
#
# Score of SVR(kernel='linear') is: 0.4362693405708138
# Error:
# Mean Absolute Error : 0.09972029878819458
# Mean Squared Error : 0.015580080241029661
# r2_score 0.42111198944073613
# *******************************************************************************************************
#
#
# Score of Lasso() is: 0.0
# Error:
# Mean Absolute Error : 0.13473117168191445
# Mean Squared Error : 0.026916152491648724
# r2_score -8.714504351936547e-05
# *******************************************************************************************************
#
#
# Score of Ridge(alpha=1) is: 0.43669416862905963
# Error:
# Mean Absolute Error : 0.09982441429073442
# Mean Squared Error : 0.015576497074223037
# r2_score 0.42124512433298955
# *******************************************************************************************************
#
#
# Score of ElasticNet() is: 0.0
# Error:
# Mean Absolute Error : 0.13473117168191445
# Mean Squared Error : 0.026916152491648724
# r2_score -8.714504351936547e-05
# *******************************************************************************************************
#
#
# Score of RandomForestRegressor() is: 0.9770063730283189
# Error:
# Mean Absolute Error : 0.047624868718708586
# Mean Squared Error : 0.004364345847539418
# r2_score 0.8378398926071444
# *******************************************************************************************************
#
#
# Score of AdaBoostRegressor() is: 0.46845603879123165
# Error:
# Mean Absolute Error : 0.09986502316532118
# Mean Squared Error : 0.015028334537585604
# r2_score 0.4416124597631049
# *******************************************************************************************************

# %%
from sklearn.model_selection import cross_val_score
for m in model:
    score=cross_val_score(m,x,y,cv=5,scoring='r2')
    print('Score of',m,'is:',score)
    print('Mean score:',score.mean())
    print('Standard deviation:',score.std())
    print('**************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression() is: [-0.98015195  0.02238092  0.49477982 -0.077422   -0.14466734]
# Mean score: -0.13701610914298423
# Standard deviation: 0.477296876896967
# **************************************************************************************
#
#
# Score of DecisionTreeRegressor() is: [-1.58883746  0.03358807  0.23956342 -0.41688522 -0.32702843]
# Mean score: -0.41191992505683145
# Standard deviation: 0.6348659752249587
# **************************************************************************************
#
#
# Score of KNeighborsRegressor() is: [-1.00086698  0.28613595  0.41827287  0.09149928 -0.13490278]
# Mean score: -0.06797233278538524
# Standard deviation: 0.502400314784999
# **************************************************************************************
#
#
# Score of SVR(kernel='linear') is: [-0.92709341  0.019992    0.49065073 -0.0915143  -0.14086021]
# Mean score: -0.12976503712371296
# Standard deviation: 0.45709116072091566
# **************************************************************************************
#
#
# Score of Lasso() is: [-3.03303991 -0.62183457 -0.02311777 -0.57606372 -0.93449679]
# Mean score: -1.0377105535400972
# Standard deviation: 1.0399482171182668
# **************************************************************************************
#
#
# Score of Ridge(alpha=1) is: [-0.98090814  0.02244775  0.49485388 -0.07646562 -0.14479467]
# Mean score: -0.1369733598207029
# Standard deviation: 0.47761260831428404
# **************************************************************************************
#
#
# Score of ElasticNet() is: [-3.03303991 -0.62183457 -0.02311777 -0.57606372 -0.93449679]
# Mean score: -1.0377105535400972
# Standard deviation: 1.0399482171182668
# **************************************************************************************
#
#
# Score of RandomForestRegressor() is: [-0.18963423  0.38668071  0.59650836  0.21036389  0.0109769 ]
# Mean score: 0.20297912596473394
# Standard deviation: 0.2755634822485905
# **************************************************************************************
#
#
# Score of AdaBoostRegressor() is: [-1.06441233  0.05674031  0.46431913  0.01496486 -0.09926416]
# Mean score: -0.12553043841534658
# Standard deviation: 0.5065714542303761
# **************************************************************************************

# %%
import joblib
joblib.dump(KNeighborsRegressor,'Avocado.pkl')
# Out:
# ['Avocado.pkl']

# %% [markdown]
# Observed: 1.KNeighboursregressor is the best model and we get accuracy score is 67 percent
